# %%
#2
import numpy as np
import matplotlib.pyplot as plt
height = np.random.normal(140, 20, 1000)
plt.figure(dpi=200)
plt.title("Height Distribuion")
plt.xlabel("Height (cm) ")
plt.ylabel("Frequency")
plt.hist(height, bins=30, ec="gold")
# Out:
# (array([ 1.,  2.,  3.,  7.,  5.,  7., 23., 17., 27., 41., 58., 52., 73.,
#         63., 86., 77., 82., 84., 62., 40., 53., 35., 38., 16., 13.,  9.,
#         10.,  7.,  4.,  5.]),
#  array([ 79.77909017,  83.68084317,  87.58259617,  91.48434917,
#          95.38610218,  99.28785518, 103.18960818, 107.09136118,
#         110.99311418, 114.89486718, 118.79662018, 122.69837318,
#         126.60012619, 130.50187919, 134.40363219, 138.30538519,
#         142.20713819, 146.10889119, 150.01064419, 153.9123972 ,
#         157.8141502 , 161.7159032 , 165.6176562 , 169.5194092 ,
#         173.4211622 , 177.3229152 , 181.2246682 , 185.12642121,
#         189.02817421, 192.92992721, 196.83168021]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# 3.Write down above code using vim on same working directory, and execute it using python interpreter, tell us difference between jupyter and notepad
#
# ANS)Jupyter is an interactive computing environment that allows you to create and share documents containing live code, equations, visualizations, and explanatory text.
# It provides a web-based interface called the Jupyter Notebook, where you can write and execute code in separate cells.
#
# Notepad is plain text editors that allow you to create and edit code files.
# It's typically used for writing code in various programming languages.
# Notepad is a basic text editor available on Windows
# With a text editor we write our code in a file, save it, and then execute it using the appropriate programming language's interpreter or compiler.

# %% [markdown]
# 4.Write Down difference between interpreter and compiler

# %% [markdown]
# ANS
# interpreter - Translates program one statement at a time.
#                They are fairly easy to use and execute, even for a beginner.
#                It doesn’t save the machine language at all.
#                The interpreted codes run comparatively slower.
#                Programming languages like JavaScript, Python, Ruby use interpreters.
#
# compiler-Scans the entire program and translates it as a whole into machine code.
#          The code execution time is comparatively less because the program code already gets translated into machine code.
#          It stores the machine language on the disk in the form of machine code.
#          The compiled codes run comparatively faster.
#          Programming languages like C, C++, Java use compilers.

# %% [markdown]
# 5.What is Data Structure, why we need one in programs?
#
#
# ans)A data structure is a specialized format for organizing, processing, retrieving and storing data
#
#      It is needed for-
#         Efficient Data Access
#         Memory Management
#         Organization and Management
#         Algorithm Design
#         Code Reusability
#         Problem Solving
